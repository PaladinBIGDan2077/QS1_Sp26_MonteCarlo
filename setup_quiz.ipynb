# %% [markdown]
# # Setup quiz
#
# Run the following cell displaying your git info:

# %%
# !git config --list
# Out:
# http.sslverify=true
# http.sslcapath=/home/dlomis/.conda/envs/molssi_best_practices/ssl/cacert.pem
# http.sslcainfo=/home/dlomis/.conda/envs/molssi_best_practices/ssl/cacert.pem
# user.email=daniellomis@yahoo.com
# user.name=Daniel Lomis
# credential.helper=store
# init.defaultbranch=main
# core.editor=nano -w
# core.repositoryformatversion=0
# core.filemode=true
# core.bare=false
# core.logallrefupdates=true
# remote.origin.url=https://github.com/PaladinBIGDan2077/QS1_Sp26_MonteCarlo.git
# remote.origin.fetch=+refs/heads/*:refs/remotes/origin/*
# branch.main.remote=origin
# branch.main.merge=refs/heads/main

# %% [markdown]
# Let's see which conda version we have installed

# %%
# !conda --version
# Out:
# conda 24.11.3

# %% [markdown]
# Make sure that you have activated the conda environment you set up for this class, and then execute the following command:

# %%
# !which python
# Out:
# /home/dlomis/.conda/envs/molssi_best_practices/bin/python

# %% [markdown]
# And which version of Python do you have?

# %%
# !python --version
import sys
assert(sys.version_info.major==3)
assert(sys.version_info.minor>=11)
# Out:
# Python 3.11.15

# %% [markdown]
# Which cookiecutter?

# %%
# !which cookiecutter
# Out:
# /home/dlomis/.conda/envs/molssi_best_practices/bin/cookiecutter

# %%
# !cookiecutter --version
import cookiecutter
assert(int(cookiecutter._get_version()[0]) >= 2)
# Out:
# Cookiecutter 2.7.1 from /home/dlomis/.conda/envs/molssi_best_practices/lib/python3.11/site-packages (Python 3.11.15 | packaged by conda-forge | (main, Mar  5 2026, 16:45:40) [GCC 14.3.0])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 get_ipython().system('cookiecutter --version')
#       2 import cookiecutter
# ----> 3 assert(int(cookiecutter._get_version()[0]) >= 2)
#
# AttributeError: module 'cookiecutter' has no attribute '_get_version'

# %%
# !which jupyter
# Out:
# /home/dlomis/.conda/envs/molssi_best_practices/bin/jupyter

# %%
# !jupyter --version
# Out:
# Selected Jupyter core packages...
# IPython          : 9.10.1
# ipykernel        : 7.2.0
# ipywidgets       : not installed
# jupyter_client   : 8.8.0
# jupyter_core     : 5.9.1
# jupyter_server   : 2.17.0
# jupyterlab       : 4.5.6
# nbclient         : 0.10.4
# nbconvert        : 7.17.0
# nbformat         : 5.10.4
# notebook         : not installed
# qtconsole        : not installed
# traitlets        : 5.14.3
